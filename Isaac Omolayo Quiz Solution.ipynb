# %%
import pandas as pd
import numpy as np

# %%
fuel_df = pd.read_csv('https://bit.ly/HDSC-StageOneDataset')
print(fuel_df)
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_df.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
fuel_df.groupby('report_year')[['fuel_cost_per_unit_delivered']].mean()
# Out:
#              fuel_cost_per_unit_delivered
# report_year
# 1994                            63.636060
# 1995                            32.735269
# 1996                          9196.705948
# 1997                         11140.197239
# 1998                           287.154420
# 1999                            25.551627
# 2000                           985.362877
# 2001                            60.050396
# 2002                            47.594361
# 2003                            55.663493
# 2004                           139.524275
# 2005                            41.438184
# 2006                            38.657484
# 2007                            43.325023
# 2008                            58.588197
# 2009                           652.694163
# 2010                            91.862105
# 2011                            59.774667
# 2012                            60.994502
# 2013                           172.307591
# 2014                           192.737183
# ...

# %%
print (' The skewness of fuel quantity burned is', fuel_df[['fuel_qty_burned']].skew())
print (' The kurtosis of fuel quantity burned is', fuel_df[['fuel_qty_burned']].kurtosis())
# Out:
#  The skewness of fuel quantity burned is fuel_qty_burned    15.851495
# dtype: float64
#  The kurtosis of fuel quantity burned is fuel_qty_burned    651.36945
# dtype: float64

# %%
fuel_df.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fuel_df.groupby('fuel_unit').count()
# Out:
#            record_id  utility_id_ferc1  report_year  plant_name_ferc1  \
# fuel_unit
# bbl             7998              7998         7998              7998
# gal               84                84           84                84
# gramsU           464               464          464               464
# kgU              110               110          110               110
# mcf            11354             11354        11354             11354
# mmbtu            180               180          180               180
# mwdth             95                95           95                95
# mwhth            100               100          100               100
# ton             8958              8958         8958              8958
#
#            fuel_type_code_pudl  fuel_qty_burned  fuel_mmbtu_per_unit  \
# fuel_unit
# bbl                       7998             7998                 7998
# gal                         84               84                   84
# ...

# %%
fuel_df[['fuel_unit']].fillna('mcf')
# Out:
#       fuel_unit
# 0           ton
# 1           ton
# 2           ton
# 3           ton
# 4           mcf
# ...         ...
# 29518       mcf
# 29519       mcf
# 29520       mcf
# 29521       ton
# 29522       mcf
#
# [29523 rows x 1 columns]

# %%
fuel_df.groupby('fuel_type_code_pudl')[['fuel_cost_per_unit_burned']].mean()
# Out:
#                      fuel_cost_per_unit_burned
# fuel_type_code_pudl
# coal                                 67.421830
# gas                                  13.659397
# nuclear                            4955.157002
# oil                                 168.877086
# other                                18.253856
# waste                                19.518122
